# %% [markdown]
# # A Study on Arrhythmia via ECG Signal Classification Using the Convolutional Neural Network

# %% [markdown]
# This is an implementation to the paper **"A Study on Arrhythmia via ECG Signal Classification Using the Convolutional Neural Network"**.
#
# The author of the paper said that the proposed algorithm is implemented in Matlab, but we cannot find this implementation, so we implemented it in Python

# %% [markdown]
# # Imports

# %%
import numpy as np 
import pandas as pd 
import os

import matplotlib.pyplot as plt
import csv
import itertools
import collections

import pywt
from scipy import stats

from sklearn.utils import resample
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.layers import Conv1D, AvgPool1D, Flatten, Dense, Dropout, Softmax
from keras.optimizers import Adam 
from keras.utils.np_utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras import regularizers
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import KFold
import os
from tensorflow.keras.models import load_model
import json

import optuna
# %matplotlib inline

# %% [markdown]
# # matplotlib Settings

# %%
plt.rcParams["figure.figsize"] = (30,6)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.color'] = 'b'
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Methods Definitions

# %%
def denoise(data): 
    w = pywt.Wavelet('sym4')
    maxlev = pywt.dwt_max_level(len(data), w.dec_len)
    threshold = 0.04 # Threshold for filtering

    coeffs = pywt.wavedec(data, 'sym4', level=maxlev)
    for i in range(1, len(coeffs)):
        coeffs[i] = pywt.threshold(coeffs[i], threshold*max(coeffs[i]))
        
    datarec = pywt.waverec(coeffs, 'sym4')
    
    return datarec

# %% [markdown]
# # Variables Definitions

# %%
path = '/kaggle/input/mitbit-arrhythmia-database/mitbih_database/'
window_size = 180
maximum_counting = 10000

classes = ['N', 'L', 'R', 'A', 'V']
n_classes = len(classes)
count_classes = [0]*n_classes

X = list()
y = list()

# %% [markdown]
# # Prepere Input Files

# %%
# Read files
filenames = next(os.walk(path))[2]

# Split and save .csv , .txt 
records = list()
annotations = list()
filenames.sort()

# %%
# segrefating filenames and annotations
for f in filenames:
    filename, file_extension = os.path.splitext(f)
    
    # *.csv
    if(file_extension == '.csv'):
        records.append(path + filename + file_extension)

    # *.txt
    else:
        annotations.append(path + filename + file_extension)

# %% [markdown]
# # Data Extraction and Preprocessing

# %%
# Records
for r in range(0,len(records)):
    signals = []

    with open(records[r], 'rt') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|') # read CSV file\
        row_index = -1
        for row in spamreader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1
            
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " Wave")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = denoise(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after denoised")
        plt.plot(signals[0:700])
        plt.show()
        
    signals = stats.zscore(signals)
    # Plot an example to the signals
    if r is 1:
        # Plot each patient's signal
        plt.title(records[1] + " wave after z-score normalization ")
        plt.plot(signals[0:700])
        plt.show()
    
    # Read anotations: R position and Arrhythmia class
    example_beat_printed = False
    with open(annotations[r], 'r') as fileID:
        data = fileID.readlines() 
        beat = list()

        for d in range(1, len(data)): # 0 index is Chart Head
            splitted = data[d].split(' ')
            splitted = filter(None, splitted)
            next(splitted) # Time... Clipping
            pos = int(next(splitted)) # Sample ID
            arrhythmia_type = next(splitted) # Type
            if(arrhythmia_type in classes):
                arrhythmia_index = classes.index(arrhythmia_type)
#                 if count_classes[arrhythmia_index] > maximum_counting: # avoid overfitting
#                     pass
#                 else:
                count_classes[arrhythmia_index] += 1
                if(window_size <= pos and pos < (len(signals) - window_size)):
                    beat = signals[pos-window_size:pos+window_size]     ## REPLACE WITH R-PEAK DETECTION
                    # Plot an example to a beat    
                    if r is 1 and not example_beat_printed: 
                        plt.title("A Beat from " + records[1] + " Wave")
                        plt.plot(beat)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)
                    y.append(arrhythmia_index)

# data shape
print(np.shape(X), np.shape(y))
# Out:
# (100012, 360) (100012,)

# %%
for i in range(0,len(X)):
        X[i] = np.append(X[i], y[i])
#         X[i].append(y[i])

print(np.shape(X))
# Out:
# (100012, 361)

# %% [markdown]
# # Classes Distribution

# %%
X_train_df = pd.DataFrame(X)
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 0.0    75011
# 1.0     8071
# 2.0     7255
# 4.0     7129
# 3.0     2546
# Name: 360, dtype: int64

# %% [markdown]
# # Rebalancing Classes

# %%
df_1=X_train_df[X_train_df[X_train_df.shape[1]-1]==1]
df_2=X_train_df[X_train_df[X_train_df.shape[1]-1]==2]
df_3=X_train_df[X_train_df[X_train_df.shape[1]-1]==3]
df_4=X_train_df[X_train_df[X_train_df.shape[1]-1]==4]
# df_5=X_train_df[X_train_df[X_train_df.shape[1]-1]==5]
df_0=(X_train_df[X_train_df[X_train_df.shape[1]-1]==0]).sample(n=3000,random_state=42)

df_1_upsample=resample(df_1,replace=True,n_samples=3000,random_state=122)
df_2_upsample=resample(df_2,replace=True,n_samples=3000,random_state=123)
df_3_upsample=resample(df_3,replace=True,n_samples=3000,random_state=124)
df_4_upsample=resample(df_4,replace=True,n_samples=3000,random_state=125)
# df_5_upsample=resample(df_5,replace=True,n_samples=5000,random_state=126)

# X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample,df_5_upsample])
X_train_df=pd.concat([df_0,df_1_upsample,df_2_upsample,df_3_upsample,df_4_upsample])

# %%
per_class = X_train_df[X_train_df.shape[1]-1].value_counts()
print(per_class)
plt.figure(figsize=(20,10))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 4.0    3000
# 3.0    3000
# 2.0    3000
# 1.0    3000
# 0.0    3000
# Name: 360, dtype: int64

# %% [markdown]
# # Train-Test Split

# %%
# Split the original dataset into train and test sets
train, test = train_test_split(X_train_df, test_size=0.20, random_state=42)

# # Further split the training set into train and validation sets
# train, val = train_test_split(train, test_size=0.25, random_state=42)  # 25% of the training set

# %%
# Prepare the target and features for training, validation, and test sets
target_train = train[train.shape[1]-1]
# target_val = val[val.shape[1]-1]
target_test = test[test.shape[1]-1]

train_y = to_categorical(target_train)
# val_y = to_categorical(target_val)
test_y = to_categorical(target_test)

# %%
train_x = train.iloc[:, :train.shape[1]-1].values
# val_x = val.iloc[:, :val.shape[1]-1].values
test_x = test.iloc[:, :test.shape[1]-1].values

train_x = train_x.reshape(len(train_x), train_x.shape[1], 1)
# val_x = val_x.reshape(len(val_x), val_x.shape[1], 1)
test_x = test_x.reshape(len(test_x), test_x.shape[1], 1)

# %%
print("Training set:", train_x.shape, train_y.shape)
# print("Validation set:", val_x.shape, val_y.shape)
print("Test set:", test_x.shape, test_y.shape)
# Out:
# Training set: (12000, 360, 1) (12000, 5)
# Test set: (3000, 360, 1) (3000, 5)

# %% [markdown]
# ## Building the Model Architecture

# %%
# Value:  0.9386666417121887
#   Params: 
#     num_layers: 2
#     num_filters_0: 80
#     num_filters_1: 64
#     kernel_size_0: 5
#     kernel_size_1: 7
#     dropout_rate: 0.3200580062760364
#     batch_size: 96
#     learn_rate: 0.0011611420918167382
#     num_epochs: 30

# %%
# Instanciate an empty model
model = Sequential()
model.add(Conv1D(filters=80, kernel_size=5, padding='same', activation='relu',input_shape=(360, 1)))
model.add(AvgPool1D(pool_size=3, strides=2))
model.add(Conv1D(filters=64, kernel_size=7, padding='same', activation='relu'))
model.add(AvgPool1D(pool_size=3, strides=2))
model.add(Flatten())
model.add(Dropout(0.3200580062760364))
model.add(Dense(35,kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))
model.add(Dense(5,kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))
model.add(Softmax())
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 360, 80)           480
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 179, 80)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 179, 64)           35904
# _________________________________________________________________
# average_pooling1d_1 (Average (None, 89, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 5696)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 5696)              0
# _________________________________________________________________
# dense (Dense)                (None, 35)                199395
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 180
# _________________________________________________________________
# softmax (Softmax)            (None, 5)                 0
# =================================================================
# Total params: 235,959
# Trainable params: 235,959
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Performing K-Fold Cross validation (K=5)

# %%
# Define K-Fold Cross Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Convert your data into NumPy arrays (if not already)
X = np.array(train_x)  # Assuming X_train_df contains features
y = np.array(train_y)  # Assuming y_train_df contains labels

# %%
# Directory to save models
save_dir = "kfold_models"
os.makedirs(save_dir, exist_ok=True)

# %%
fold = 1
# Loop through each fold
for train_index, val_index in kf.split(X):
    # Split the data into training and validation sets
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Build and compile your model here
    model = Sequential()
    model.add(Conv1D(filters=80, kernel_size=5, padding='same', activation='relu',input_shape=(360, 1)))
    model.add(AvgPool1D(pool_size=3, strides=2))
    model.add(Conv1D(filters=64, kernel_size=7, padding='same', activation='relu'))
    model.add(AvgPool1D(pool_size=3, strides=2))
    model.add(Flatten())
    model.add(Dropout(0.3200580062760364))
    model.add(Dense(35,kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(5,kernel_regularizer=regularizers.l2(0.0001), bias_regularizer=regularizers.l2(0.0001)))
    model.add(Softmax())

    # Compiling the model
    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate = 0.0011611420918167382), metrics=['accuracy'])
    # Train the model
    history = model.fit(
        X_train, y_train,
        batch_size=96, epochs=30,
        verbose=1,
        validation_data=(X_val, y_val)
    )

    # Evaluate the model on the validation set
    val_loss, val_accuracy = model.evaluate(X_val, y_val)
    print(f"Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}")

    # Save training history
    history_path = os.path.join(save_dir, f"history_fold_{fold}.json")
    with open(history_path, "w") as f:
        json.dump(history.history, f)
        
    print(f"Training history for fold {fold} saved at: {history_path}")

    # Saving Model
    model_path = os.path.join(save_dir, f"model_fold_{fold}.h5")
    model.save(model_path)
    print(f"Model for fold {fold} saved at: {model_path}")
    
    fold += 1
    print(f"="*80)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 7s 12ms/step - loss: 0.8794 - accuracy: 0.7070 - val_loss: 0.3471 - val_accuracy: 0.9025
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3170 - accuracy: 0.9082 - val_loss: 0.2735 - val_accuracy: 0.9254
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2430 - accuracy: 0.9317 - val_loss: 0.2589 - val_accuracy: 0.9250
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2206 - accuracy: 0.9321 - val_loss: 0.2737 - val_accuracy: 0.9275
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2131 - accuracy: 0.9389 - val_loss: 0.2777 - val_accuracy: 0.9171
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1909 - accuracy: 0.9448 - val_loss: 0.2543 - val_accuracy: 0.9283
# Epoch 7/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1780 - accuracy: 0.9525 - val_loss: 0.2432 - val_accuracy: 0.9333
# Epoch 8/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1791 - accuracy: 0.9496 - val_loss: 0.2260 - val_accuracy: 0.9379
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1713 - accuracy: 0.9487 - val_loss: 0.2228 - val_accuracy: 0.9413
# Epoch 10/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1530 - accuracy: 0.9554 - val_loss: 0.2110 - val_accuracy: 0.9425
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1477 - accuracy: 0.9577 - val_loss: 0.2185 - val_accuracy: 0.9429
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1373 - accuracy: 0.9610 - val_loss: 0.2013 - val_accuracy: 0.9513
# Epoch 13/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1373 - accuracy: 0.9618 - val_loss: 0.2103 - val_accuracy: 0.9504
# Epoch 14/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1316 - accuracy: 0.9615 - val_loss: 0.1997 - val_accuracy: 0.9529
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1338 - accuracy: 0.9630 - val_loss: 0.2065 - val_accuracy: 0.9500
# Epoch 16/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1199 - accuracy: 0.9652 - val_loss: 0.2103 - val_accuracy: 0.9488
# Epoch 17/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1174 - accuracy: 0.9691 - val_loss: 0.2084 - val_accuracy: 0.9504
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1158 - accuracy: 0.9641 - val_loss: 0.2041 - val_accuracy: 0.9496
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1175 - accuracy: 0.9689 - val_loss: 0.2046 - val_accuracy: 0.9500
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1199 - accuracy: 0.9677 - val_loss: 0.1994 - val_accuracy: 0.9554
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1064 - accuracy: 0.9723 - val_loss: 0.1971 - val_accuracy: 0.9529
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1032 - accuracy: 0.9742 - val_loss: 0.2108 - val_accuracy: 0.9546
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1042 - accuracy: 0.9749 - val_loss: 0.1996 - val_accuracy: 0.9500
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1068 - accuracy: 0.9723 - val_loss: 0.1829 - val_accuracy: 0.9533
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0954 - accuracy: 0.9749 - val_loss: 0.1833 - val_accuracy: 0.9538
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1040 - accuracy: 0.9740 - val_loss: 0.1859 - val_accuracy: 0.9563
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0965 - accuracy: 0.9766 - val_loss: 0.1915 - val_accuracy: 0.9558
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0893 - accuracy: 0.9798 - val_loss: 0.2056 - val_accuracy: 0.9558
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0963 - accuracy: 0.9775 - val_loss: 0.2084 - val_accuracy: 0.9500
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0945 - accuracy: 0.9793 - val_loss: 0.1847 - val_accuracy: 0.9550
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1847 - accuracy: 0.9550
# Validation Loss: 0.18472182750701904, Validation Accuracy: 0.9549999833106995
# Training history for fold 1 saved at: kfold_models/history_fold_1.json
# Model for fold 1 saved at: kfold_models/model_fold_1.h5
# ================================================================================
# Epoch 1/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.8258 - accuracy: 0.7061 - val_loss: 0.3485 - val_accuracy: 0.9079
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3114 - accuracy: 0.9167 - val_loss: 0.2821 - val_accuracy: 0.9108
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2444 - accuracy: 0.9264 - val_loss: 0.2371 - val_accuracy: 0.9308
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2253 - accuracy: 0.9305 - val_loss: 0.2342 - val_accuracy: 0.9325
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1949 - accuracy: 0.9415 - val_loss: 0.2185 - val_accuracy: 0.9404
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2002 - accuracy: 0.9399 - val_loss: 0.2183 - val_accuracy: 0.9383
# Epoch 7/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1727 - accuracy: 0.9478 - val_loss: 0.1752 - val_accuracy: 0.9467
# Epoch 8/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1610 - accuracy: 0.9565 - val_loss: 0.1909 - val_accuracy: 0.9471
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1685 - accuracy: 0.9504 - val_loss: 0.1930 - val_accuracy: 0.9488
# Epoch 10/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1589 - accuracy: 0.9549 - val_loss: 0.1739 - val_accuracy: 0.9563
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1389 - accuracy: 0.9625 - val_loss: 0.1783 - val_accuracy: 0.9513
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1446 - accuracy: 0.9564 - val_loss: 0.1673 - val_accuracy: 0.9563
# Epoch 13/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1363 - accuracy: 0.9629 - val_loss: 0.1795 - val_accuracy: 0.9517
# Epoch 14/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1377 - accuracy: 0.9621 - val_loss: 0.1667 - val_accuracy: 0.9608
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1327 - accuracy: 0.9613 - val_loss: 0.1629 - val_accuracy: 0.9583
# Epoch 16/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1165 - accuracy: 0.9686 - val_loss: 0.1623 - val_accuracy: 0.9592
# Epoch 17/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1205 - accuracy: 0.9671 - val_loss: 0.1675 - val_accuracy: 0.9583
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1297 - accuracy: 0.9662 - val_loss: 0.1559 - val_accuracy: 0.9596
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1155 - accuracy: 0.9709 - val_loss: 0.1692 - val_accuracy: 0.9604
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1127 - accuracy: 0.9680 - val_loss: 0.1670 - val_accuracy: 0.9608
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1038 - accuracy: 0.9730 - val_loss: 0.1509 - val_accuracy: 0.9683
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1051 - accuracy: 0.9731 - val_loss: 0.1607 - val_accuracy: 0.9663
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1046 - accuracy: 0.9734 - val_loss: 0.1692 - val_accuracy: 0.9608
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1027 - accuracy: 0.9729 - val_loss: 0.1361 - val_accuracy: 0.9683
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0927 - accuracy: 0.9789 - val_loss: 0.1514 - val_accuracy: 0.9675
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0972 - accuracy: 0.9767 - val_loss: 0.1563 - val_accuracy: 0.9642
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0979 - accuracy: 0.9745 - val_loss: 0.1501 - val_accuracy: 0.9658
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0937 - accuracy: 0.9772 - val_loss: 0.1440 - val_accuracy: 0.9704
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0858 - accuracy: 0.9793 - val_loss: 0.1685 - val_accuracy: 0.9588
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0924 - accuracy: 0.9772 - val_loss: 0.1518 - val_accuracy: 0.9696
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1518 - accuracy: 0.9696
# Validation Loss: 0.15181207656860352, Validation Accuracy: 0.9695833325386047
# Training history for fold 2 saved at: kfold_models/history_fold_2.json
# Model for fold 2 saved at: kfold_models/model_fold_2.h5
# ================================================================================
# Epoch 1/30
# 100/100 [==============================] - 2s 8ms/step - loss: 0.8925 - accuracy: 0.6728 - val_loss: 0.3068 - val_accuracy: 0.9075
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3101 - accuracy: 0.9084 - val_loss: 0.2477 - val_accuracy: 0.9217
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2627 - accuracy: 0.9192 - val_loss: 0.2270 - val_accuracy: 0.9325
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2235 - accuracy: 0.9326 - val_loss: 0.2157 - val_accuracy: 0.9292
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1988 - accuracy: 0.9380 - val_loss: 0.1943 - val_accuracy: 0.9438
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1873 - accuracy: 0.9445 - val_loss: 0.2249 - val_accuracy: 0.9371
# Epoch 7/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1868 - accuracy: 0.9460 - val_loss: 0.1850 - val_accuracy: 0.9508
# Epoch 8/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1758 - accuracy: 0.9475 - val_loss: 0.1692 - val_accuracy: 0.9575
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1557 - accuracy: 0.9564 - val_loss: 0.1887 - val_accuracy: 0.9417
# Epoch 10/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1482 - accuracy: 0.9557 - val_loss: 0.1695 - val_accuracy: 0.9575
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1403 - accuracy: 0.9598 - val_loss: 0.1784 - val_accuracy: 0.9588
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1444 - accuracy: 0.9616 - val_loss: 0.1593 - val_accuracy: 0.9613
# Epoch 13/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1387 - accuracy: 0.9598 - val_loss: 0.1698 - val_accuracy: 0.9558
# Epoch 14/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1333 - accuracy: 0.9632 - val_loss: 0.1531 - val_accuracy: 0.9600
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1189 - accuracy: 0.9655 - val_loss: 0.1570 - val_accuracy: 0.9604
# Epoch 16/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1249 - accuracy: 0.9664 - val_loss: 0.1524 - val_accuracy: 0.9654
# Epoch 17/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1142 - accuracy: 0.9695 - val_loss: 0.1519 - val_accuracy: 0.9646
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1115 - accuracy: 0.9709 - val_loss: 0.1537 - val_accuracy: 0.9604
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1111 - accuracy: 0.9716 - val_loss: 0.1570 - val_accuracy: 0.9596
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1195 - accuracy: 0.9670 - val_loss: 0.1610 - val_accuracy: 0.9638
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1088 - accuracy: 0.9729 - val_loss: 0.1480 - val_accuracy: 0.9646
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1091 - accuracy: 0.9714 - val_loss: 0.1550 - val_accuracy: 0.9638
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1039 - accuracy: 0.9720 - val_loss: 0.1534 - val_accuracy: 0.9667
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0979 - accuracy: 0.9747 - val_loss: 0.1463 - val_accuracy: 0.9683
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1019 - accuracy: 0.9716 - val_loss: 0.1607 - val_accuracy: 0.9646
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1000 - accuracy: 0.9726 - val_loss: 0.1541 - val_accuracy: 0.9654
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0995 - accuracy: 0.9746 - val_loss: 0.1575 - val_accuracy: 0.9650
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1059 - accuracy: 0.9738 - val_loss: 0.1492 - val_accuracy: 0.9704
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0894 - accuracy: 0.9778 - val_loss: 0.1646 - val_accuracy: 0.9671
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0949 - accuracy: 0.9742 - val_loss: 0.1364 - val_accuracy: 0.9725
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1364 - accuracy: 0.9725
# Validation Loss: 0.13642467558383942, Validation Accuracy: 0.9725000262260437
# Training history for fold 3 saved at: kfold_models/history_fold_3.json
# Model for fold 3 saved at: kfold_models/model_fold_3.h5
# ================================================================================
# Epoch 1/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.8519 - accuracy: 0.7038 - val_loss: 0.3137 - val_accuracy: 0.9133
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3256 - accuracy: 0.9050 - val_loss: 0.2643 - val_accuracy: 0.9242
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2683 - accuracy: 0.9200 - val_loss: 0.2524 - val_accuracy: 0.9283
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2233 - accuracy: 0.9373 - val_loss: 0.2113 - val_accuracy: 0.9417
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2165 - accuracy: 0.9325 - val_loss: 0.2084 - val_accuracy: 0.9417
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2126 - accuracy: 0.9403 - val_loss: 0.2050 - val_accuracy: 0.9417
# Epoch 7/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1825 - accuracy: 0.9463 - val_loss: 0.1887 - val_accuracy: 0.9508
# Epoch 8/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1736 - accuracy: 0.9512 - val_loss: 0.1944 - val_accuracy: 0.9429
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1880 - accuracy: 0.9448 - val_loss: 0.1786 - val_accuracy: 0.9488
# Epoch 10/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1533 - accuracy: 0.9562 - val_loss: 0.1803 - val_accuracy: 0.9533
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1620 - accuracy: 0.9550 - val_loss: 0.1774 - val_accuracy: 0.9500
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1384 - accuracy: 0.9631 - val_loss: 0.1834 - val_accuracy: 0.9525
# Epoch 13/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1322 - accuracy: 0.9625 - val_loss: 0.1678 - val_accuracy: 0.9550
# Epoch 14/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1333 - accuracy: 0.9627 - val_loss: 0.1640 - val_accuracy: 0.9563
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1251 - accuracy: 0.9661 - val_loss: 0.1995 - val_accuracy: 0.9479
# Epoch 16/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1322 - accuracy: 0.9624 - val_loss: 0.1647 - val_accuracy: 0.9617
# Epoch 17/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1455 - accuracy: 0.9593 - val_loss: 0.1784 - val_accuracy: 0.9588
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1320 - accuracy: 0.9601 - val_loss: 0.1658 - val_accuracy: 0.9579
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1142 - accuracy: 0.9691 - val_loss: 0.1664 - val_accuracy: 0.9567
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1082 - accuracy: 0.9723 - val_loss: 0.1571 - val_accuracy: 0.9583
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1024 - accuracy: 0.9746 - val_loss: 0.1507 - val_accuracy: 0.9617
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1109 - accuracy: 0.9697 - val_loss: 0.1508 - val_accuracy: 0.9604
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1087 - accuracy: 0.9682 - val_loss: 0.1878 - val_accuracy: 0.9488
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1108 - accuracy: 0.9693 - val_loss: 0.1573 - val_accuracy: 0.9592
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0997 - accuracy: 0.9735 - val_loss: 0.1551 - val_accuracy: 0.9625
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1045 - accuracy: 0.9702 - val_loss: 0.1535 - val_accuracy: 0.9608
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1052 - accuracy: 0.9713 - val_loss: 0.1628 - val_accuracy: 0.9625
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1114 - accuracy: 0.9683 - val_loss: 0.1447 - val_accuracy: 0.9621
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0951 - accuracy: 0.9772 - val_loss: 0.1436 - val_accuracy: 0.9625
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0980 - accuracy: 0.9752 - val_loss: 0.1467 - val_accuracy: 0.9646
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9646
# Validation Loss: 0.14668972790241241, Validation Accuracy: 0.9645833373069763
# Training history for fold 4 saved at: kfold_models/history_fold_4.json
# Model for fold 4 saved at: kfold_models/model_fold_4.h5
# ================================================================================
# Epoch 1/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.8915 - accuracy: 0.6715 - val_loss: 0.3042 - val_accuracy: 0.9104
# Epoch 2/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3294 - accuracy: 0.8997 - val_loss: 0.2178 - val_accuracy: 0.9296
# Epoch 3/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2499 - accuracy: 0.9269 - val_loss: 0.2044 - val_accuracy: 0.9429
# Epoch 4/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2364 - accuracy: 0.9304 - val_loss: 0.1773 - val_accuracy: 0.9492
# Epoch 5/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1947 - accuracy: 0.9420 - val_loss: 0.1577 - val_accuracy: 0.9533
# Epoch 6/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1965 - accuracy: 0.9395 - val_loss: 0.1831 - val_accuracy: 0.9375
# Epoch 7/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1928 - accuracy: 0.9434 - val_loss: 0.1509 - val_accuracy: 0.9571
# Epoch 8/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1568 - accuracy: 0.9562 - val_loss: 0.1417 - val_accuracy: 0.9588
# Epoch 9/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1592 - accuracy: 0.9537 - val_loss: 0.1518 - val_accuracy: 0.9550
# Epoch 10/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1592 - accuracy: 0.9539 - val_loss: 0.1504 - val_accuracy: 0.9579
# Epoch 11/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1540 - accuracy: 0.9551 - val_loss: 0.1413 - val_accuracy: 0.9563
# Epoch 12/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1503 - accuracy: 0.9559 - val_loss: 0.1301 - val_accuracy: 0.9588
# Epoch 13/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1416 - accuracy: 0.9619 - val_loss: 0.1409 - val_accuracy: 0.9625
# Epoch 14/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1412 - accuracy: 0.9608 - val_loss: 0.1308 - val_accuracy: 0.9658
# Epoch 15/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1242 - accuracy: 0.9649 - val_loss: 0.1387 - val_accuracy: 0.9600
# Epoch 16/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1189 - accuracy: 0.9670 - val_loss: 0.1426 - val_accuracy: 0.9575
# Epoch 17/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1287 - accuracy: 0.9640 - val_loss: 0.1171 - val_accuracy: 0.9671
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1107 - accuracy: 0.9713 - val_loss: 0.1180 - val_accuracy: 0.9675
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1126 - accuracy: 0.9676 - val_loss: 0.1192 - val_accuracy: 0.9671
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1140 - accuracy: 0.9712 - val_loss: 0.1318 - val_accuracy: 0.9642
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1097 - accuracy: 0.9697 - val_loss: 0.1130 - val_accuracy: 0.9729
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1088 - accuracy: 0.9722 - val_loss: 0.1157 - val_accuracy: 0.9679
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1093 - accuracy: 0.9725 - val_loss: 0.1254 - val_accuracy: 0.9675
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1101 - accuracy: 0.9712 - val_loss: 0.1139 - val_accuracy: 0.9717
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1154 - accuracy: 0.9705 - val_loss: 0.1459 - val_accuracy: 0.9592
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1141 - accuracy: 0.9700 - val_loss: 0.1172 - val_accuracy: 0.9712
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0993 - accuracy: 0.9750 - val_loss: 0.1307 - val_accuracy: 0.9654
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1038 - accuracy: 0.9734 - val_loss: 0.1155 - val_accuracy: 0.9712
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0986 - accuracy: 0.9761 - val_loss: 0.1180 - val_accuracy: 0.9692
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1055 - accuracy: 0.9747 - val_loss: 0.1108 - val_accuracy: 0.9737
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9737
# Validation Loss: 0.11078427731990814, Validation Accuracy: 0.9737499952316284
# Training history for fold 5 saved at: kfold_models/history_fold_5.json
# Model for fold 5 saved at: kfold_models/model_fold_5.h5
# ================================================================================

# %%
# model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# ## Fitting the model

# %%
# history = model.fit(train_x, train_y, batch_size=36, epochs=60, verbose=1, validation_data=(val_x, val_y))

# %%
# Directory where history JSON files are stored
history_dir = "kfold_models"

# Initialize lists to store metrics for each fold
results = {
    "Fold": [],
    "Train Accuracy": [],
    "Train Loss": [],
    "Validation Accuracy": [],
    "Validation Loss": []
}

# Loop through the JSON files for each fold
for fold in range(1, 6):  # Assuming 5 folds
    history_path = os.path.join(history_dir, f"history_fold_{fold}.json")
    
    # Load the history file
    with open(history_path, "r") as f:
        history = json.load(f)
    
    # Extract the final metrics from the history
    train_loss = history["loss"][-1]
    train_acc = history["accuracy"][-1]
    val_loss = history["val_loss"][-1]
    val_acc = history["val_accuracy"][-1]
    
    # Append the results for the current fold
    results["Fold"].append(fold)
    results["Train Accuracy"].append(train_acc)
    results["Train Loss"].append(train_loss)
    results["Validation Accuracy"].append(val_acc)
    results["Validation Loss"].append(val_loss)

# %% [markdown]
# ### Summary of KFolds

# %%
# Convert results to a pandas DataFrame
results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#    Fold  Train Accuracy  Train Loss  Validation Accuracy  Validation Loss
# 0     1        0.976042    0.100353             0.955000         0.184722
# 1     2        0.976042    0.094846             0.969583         0.151812
# 2     3        0.974792    0.095761             0.972500         0.136425
# 3     4        0.976771    0.096233             0.964583         0.146690
# 4     5        0.978229    0.095832             0.973750         0.110784

# %% [markdown]
# ### Saving KFold models and their training history

# %%
# !zip -r output_folder.zip kfold_models
# Out:
#   adding: kfold_models/ (stored 0%)
#   adding: kfold_models/history_fold_1.json (deflated 57%)
#   adding: kfold_models/model_fold_3.h5 (deflated 8%)
#   adding: kfold_models/model_fold_5.h5 (deflated 8%)
#   adding: kfold_models/model_fold_1.h5 (deflated 8%)
#   adding: kfold_models/history_fold_4.json (deflated 57%)
#   adding: kfold_models/history_fold_5.json (deflated 57%)
#   adding: kfold_models/model_fold_4.h5 (deflated 7%)
#   adding: kfold_models/model_fold_2.h5 (deflated 8%)
#   adding: kfold_models/history_fold_3.json (deflated 58%)
#   adding: kfold_models/history_fold_2.json (deflated 57%)

# %%
# !ls /kaggle/working/
# Out:
# kfold_models  output_folder.zip

# %% [markdown]
# **Plotting the loss convergence**

# %%
# Path to the history file for the last fold (best-performing model)
history_path = "kfold_models/history_fold_5.json"  # Update this with the correct file name if needed

# Load the history file
with open(history_path, "r") as f:
    best_model_history = json.load(f)

# Plot loss
plt.plot(best_model_history['loss'], label='Train Loss')
plt.plot(best_model_history['val_loss'], label='Validation Loss')
plt.title('Model Loss (Best Performing Model - Last Fold)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Plotting accuracy**

# %%
# Plot loss
plt.plot(best_model_history['accuracy'], label='Train Loss')
plt.plot(best_model_history['val_accuracy'], label='Validation Loss')
plt.title('Model Loss (Best Performing Model - Last Fold)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Finding the performance on test Data of the best performing model

# %%
from tensorflow.keras.models import load_model

# Path to the saved model file for the best-performing model (e.g., the last fold)
model_path = "kfold_models/model_fold_5.h5"  # Update this path if needed

# Load the model
best_model = load_model(model_path)

best_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 360, 80)           480
# _________________________________________________________________
# average_pooling1d_10 (Averag (None, 179, 80)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 179, 64)           35904
# _________________________________________________________________
# average_pooling1d_11 (Averag (None, 89, 64)            0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 5696)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5696)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 35)                199395
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 180
# _________________________________________________________________
# softmax_5 (Softmax)          (None, 5)                 0
# =================================================================
# Total params: 235,959
# Trainable params: 235,959
# Non-trainable params: 0
# _________________________________________________________________

# %%
score = best_model.evaluate(test_x, test_y)

print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 94/94 [==============================] - 1s 4ms/step - loss: 0.1181 - accuracy: 0.9713
# Test Loss: 0.11805962026119232
# Test accuracy: 0.9713333249092102

# %%
from tensorflow.keras.models import Model
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Specify the intermediate layer name
layer_name = 'dense_10'  # Replace with the actual layer name in your model
intermediate_model = Model(inputs=best_model.input, outputs=best_model.get_layer(layer_name).output)

# Extract intermediate features
intermediate_features = intermediate_model.predict(test_x)  # test_x should be your test dataset

# %%
# Apply PCA
pca = PCA(n_components=2)
pca_features = pca.fit_transform(intermediate_features)

# %%
# Print explained variance
print(f"Explained variance by components: {pca.explained_variance_ratio_}")
# Out:
# Explained variance by components: [0.5197069  0.22661549]

# %%
true_classes = np.argmax(test_y, axis=1)
true_classes
# Out:
# array([3, 2, 4, ..., 3, 4, 4])

# %%
# Visualize PCA results
plt.figure(figsize=(10, 8))
sns.scatterplot(x=pca_features[:, 0], y=pca_features[:, 1], hue=true_classes, palette="viridis", s=50)
plt.title("PCA Visualization of Intermediate Features")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Class", loc='best')
plt.show()

# %%
# Extract features from intermediate layer
layer_name = 'flatten_5'
intermediate_model = Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
intermediate_features = intermediate_model.predict(test_x)

# %%
# Apply PCA
pca = PCA(n_components=2)
pca_features = pca.fit_transform(intermediate_features)

# %%
# Print explained variance
print(f"Explained variance by components: {pca.explained_variance_ratio_}")
# Out:
# Explained variance by components: [0.18389685 0.14307024]

# %%
# Visualize PCA results
plt.figure(figsize=(10, 8))
sns.scatterplot(x=pca_features[:, 0], y=pca_features[:, 1], hue=true_classes, palette="viridis", s=50)
plt.title("PCA Visualization of Intermediate Features")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Class", loc='best')
plt.show()

# %%
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# Define a model that outputs activations from a specific convolutional layer
layer_name = 'conv1d_10'  # Replace with your convolutional layer's name
intermediate_model = Model(inputs=model.input, outputs=model.get_layer(layer_name).output)

# Pass a single ECG signal through the intermediate model
test_sample = test_x[0:1]  # Select a single test sample
activation_maps = intermediate_model.predict(test_sample)

print("Activation Maps Shape:", activation_maps.shape)
# Shape: (batch_size, sequence_length, num_filters)
# Out:
# Activation Maps Shape: (1, 360, 80)

# %%
# Normalize the first filter's activation map
filter_activation = activation_maps[0, :, 0]
normalized_activation = filter_activation / max(filter_activation)

# Plot the original ECG signal and the activation map
plt.figure(figsize=(12, 4))
plt.plot(test_sample[0, :, 0], label="ECG Signal")  # Plot the original signal
plt.plot(normalized_activation * max(test_sample[0, :, 0]), label="Filter Activation (Scaled)", alpha=0.7)
plt.legend()
plt.title("ECG Signal with Filter Activation Overlay")
plt.show()

# %% [markdown]
# his plot overlays the ECG signal and the filter activation, which gives insights into which regions of the signal are strongly activating the selected filter.
#
# Interpretation
# Filter Activation Peaks:
#
# The orange line shows the scaled activation of the filter, which peaks significantly near the sharp QRS complex in the ECG signal (around index 150–200).
# This suggests that the filter is likely specialized in detecting high-frequency or high-amplitude components, such as the QRS complex.
# Focus of the Filter:
#
# Since the QRS complex corresponds to the ventricular depolarization, the filter might be focusing on sharp transitions or high-energy regions in the signal.
# Other Regions:
#
# The activation is minimal in flat or low-amplitude regions (e.g., P-wave and T-wave areas), meaning this filter doesn't respond strongly to those segments.
